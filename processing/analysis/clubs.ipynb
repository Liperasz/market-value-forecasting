# %%
import pandas as pd
import os
import numpy as np
from dotenv import load_dotenv
import matplotlib.pyplot as plt
import seaborn as sns

# %%
load_dotenv()
# Out:
# True

# %%
# definindo os caminhos
path = os.getenv('DATASETS_PATH')
# carregando dataset de clubs
df = pd.read_csv(path + '/clubs.csv')
df.head()
# Out:
#    club_id            club_code                   name  \
# 0       10    arminia-bielefeld      Arminia Bielefeld
# 1    10004             paris-fc    Paris Football Club
# 2    10010  esporte-clube-bahia    Esporte Clube Bahia
# 3     1003       leicester-city         Leicester City
# 4     1005             us-lecce  Unione Sportiva Lecce
#
#   domestic_competition_id  total_market_value  squad_size  average_age  \
# 0                      L1                 NaN          27         25.3
# 1                     FR1                 NaN          31         28.8
# 2                    BRA1                 NaN          31         26.8
# 3                     GB1                 NaN          29         25.9
# 4                     IT1                 NaN          27         25.3
#
#    foreigners_number  foreigners_percentage  national_team_players  \
# 0                 15                   55.6                      4
# 1                 17                   54.8                      9
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 796 entries, 0 to 795
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   club_id                  796 non-null    int64
#  1   club_code                796 non-null    object
#  2   name                     796 non-null    object
#  3   domestic_competition_id  796 non-null    object
#  4   total_market_value       0 non-null      float64
#  5   squad_size               796 non-null    int64
#  6   average_age              758 non-null    float64
#  7   foreigners_number        796 non-null    int64
#  8   foreigners_percentage    738 non-null    float64
#  9   national_team_players    796 non-null    int64
#  10  stadium_name             796 non-null    object
#  11  stadium_seats            796 non-null    int64
#  12  net_transfer_record      796 non-null    object
#  13  coach_name               90 non-null     object
# ...

# %%
# vendo o formato das colunas total_market_value e net_transfer_record
df[['name', 'total_market_value', 'net_transfer_record']].head()
# Out:
#                     name  total_market_value net_transfer_record
# 0      Arminia Bielefeld                 NaN             +€5.90m
# 1    Paris Football Club                 NaN            €-72.30m
# 2    Esporte Clube Bahia                 NaN             +€8.14m
# 3         Leicester City                 NaN            +€57.30m
# 4  Unione Sportiva Lecce                 NaN             +€8.62m

# %%
# vendo quantos clubes distintos existem
df['club_id'].nunique()
# Out:
# 796

# %%
# vendo quantos clubes têm domestic_competition_id preenchido
df['domestic_competition_id'].notna().sum()
# Out:
# 796

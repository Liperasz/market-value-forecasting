# %%
import pandas as pd
import os
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
# carregando dataset de players
path = os.getenv('DATASETS_PATH')
df = pd.read_csv(path + '/players.csv')
df.head()
# Out:
#    player_id first_name     last_name                name  last_season  \
# 0         10   Miroslav         Klose      Miroslav Klose         2015
# 1         26      Roman  Weidenfeller  Roman Weidenfeller         2017
# 2         65    Dimitar      Berbatov    Dimitar Berbatov         2015
# 3         77        NaN         Lúcio               Lúcio         2012
# 4         80        Tom        Starke          Tom Starke         2017
#
#    current_club_id         player_code    country_of_birth city_of_birth  \
# 0              398      miroslav-klose              Poland         Opole
# 1               16  roman-weidenfeller             Germany          Diez
# 2             1091    dimitar-berbatov            Bulgaria   Blagoevgrad
# 3              506               lucio              Brazil      Brasília
# 4               27          tom-starke  East Germany (GDR)       Freital
#
#   country_of_citizenship  ...            agent_name  \
# ...

# %%
# vendo informações do dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48380 entries, 0 to 48379
# Data columns (total 26 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   player_id                             48380 non-null  int64
#  1   first_name                            45255 non-null  object
#  2   last_name                             48380 non-null  object
#  3   name                                  48380 non-null  object
#  4   last_season                           48380 non-null  int64
#  5   current_club_id                       48380 non-null  int64
#  6   player_code                           48380 non-null  object
#  7   country_of_birth                      43065 non-null  object
#  8   city_of_birth                         43343 non-null  object
#  9   country_of_citizenship                48109 non-null  object
#  10  date_of_birth                         48331 non-null  object
# ...

# %%
# vendo a disposição das posições
df['position'].value_counts()
# Out:
# position
# Defender      15414
# Midfield      13786
# Attack        13064
# Goalkeeper     5611
# Missing         505
# Name: count, dtype: int64

# %%
# vendo as posições especificas
df['sub_position'].value_counts()
# Out:
# sub_position
# Centre-Back           8452
# Centre-Forward        6537
# Goalkeeper            5611
# Central Midfield      5288
# Defensive Midfield    3993
# Right-Back            3569
# Left-Back             3393
# Attacking Midfield    3386
# Left Winger           3176
# Right Winger          3072
# Right Midfield         564
# Left Midfield          555
# Second Striker         279
# Name: count, dtype: int64

# %%
# vendo quantos valores nulos tem na coluna de altura do jogador
df['height_in_cm'].isna().sum()
# Out:
# 3783

# %%
# vendo quantos valores nulos tem no geral
df.isna().sum()
# Out:
# player_id                                   0
# first_name                               3125
# last_name                                   0
# name                                        0
# last_season                                 0
# current_club_id                             0
# player_code                                 0
# country_of_birth                         5315
# city_of_birth                            5037
# country_of_citizenship                    271
# date_of_birth                              49
# sub_position                              505
# position                                    0
# foot                                     5288
# height_in_cm                             3783
# contract_expiration_date                16632
# agent_name                              22517
# image_url                                   0
# international_caps                      30025
# international_goals                     30025
# ...

# %%
# vendo as distribuições de nacionalidade
df['country_of_citizenship'].value_counts()
# Out:
# country_of_citizenship
# Brazil        2698
# Spain         2167
# Italy         1991
# France        1886
# Argentina     1731
#               ...
# Macao            1
# Réunion          1
# Vanuatu          1
# Seychelles       1
# Sudan            1
# Name: count, Length: 202, dtype: int64
